# %% [markdown]
# ## Temperature data by Country
# Unless otherwise noted temperatures in fahrenheit and CO2 thousands metric tons will be displayed in separate charts because of scale differences.
#
# ## Temperature Data Source:
# * Data.World: https://data.world/data-society/global-climate-change-data
# * Original Data Source:
# * Kaggle: https://www.kaggle.com/berkeleyearth/climate-change-earth-surface-temperature-data
# * Berkeley Earth Raw data:  http://berkeleyearth.org/data/
# * Explains their data cleansing process: http://berkeleyearth.org/about-data-set/
#
#
# ## Countries with CO2 and Temperature data 1850 - 2012
# Sweden,
# Canada,
# France,
# UK,
# Spain,
# Poland
#
# ## Countries with CO2 and Temperature data 1878 - 2012
# USA,
# Australia,
# India
#
# ## G20 Countries
# The G20 consists of Argentina, Australia, Brazil, Canada, China, France, Germany, India, Indonesia, Italy, Japan, Mexico, Russia, Saudi Arabia, South Africa, South Korea, Turkey, United Kingdom, United States, and the European Union.

# %%
import pandas as pd
import numpy as np
import scipy as sp
import seaborn as sns
# Set my default color palette
mycolors = ["royalblue", "blue", "red", "green", "cyan", "orange", 
            "purple", "olive", "limegreen", "magenta", ]
sns.set_palette(mycolors)

# %%
# Store filepath in a variable: use parse_dates=["date"] 
# 
gltc = "./data/clean/clean_YearlyLandAvgTempsByCountry.csv"

# Read our Data file with the pandas library
gltc_df = pd.read_csv(gltc,encoding="ISO-8859-1")
print(len(gltc_df.index))
gltc_df.info()
# Out:
# 45358
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45358 entries, 0 to 45357
# Data columns (total 5 columns):
# year                       45358 non-null int64
# country                    45358 non-null object
# avg_yly_tmp_f              45358 non-null float64
# avg_yly_tmp_c              45358 non-null float64
# avg_yly_tmp_uncertainty    45358 non-null float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 1.7+ MB

# %%
gltc1_df = gltc_df.loc[(gltc_df["country"] == "United States") &
                       (gltc_df["year"]>= 1878)]
gltc1_df = gltc1_df.sort_values(["year"], ascending=[True]).\
                                reset_index(drop=True)
print(len(gltc1_df.index))
# Out:
# 135

# %%
# Get the min and max date range
gltc1_min_tmp = gltc1_df["avg_yly_tmp_f"].min()
gltc1_max_tmp = gltc1_df["avg_yly_tmp_f"].max()
print("min temperature (F) " + str(gltc1_min_tmp) +\
      " max temperature (F) " + \
      str(gltc1_max_tmp))
# Out:
# min temperature (F) 45.8051 max temperature (F) 50.46995

# %%
# Get the min and max date range
gltc1_min_date = gltc1_df["year"].min()
gltc1_max_date = gltc1_df["year"].max()
print("min year " + str(gltc1_min_date) + " max year " + \
      str(gltc1_max_date))
# Out:
# min year 1878 max year 2012

# %%
# Dependencies
from matplotlib.figure import Figure
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import datetime as dt
from datetime import datetime, date, time
import matplotlib.dates as mdates

fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(111)

x_axis = gltc1_df["year"]  
y_axis = gltc1_df["avg_yly_tmp_f"]

ax.set_title("USA Yearly Average Temperatures 1878 - 2012",\
             weight='bold').set_fontsize('18')
ax.set_xlabel("1878 - 2012",weight='bold').set_fontsize('14')
ax.set_ylabel("Yearly Average Temperatures(F)",weight='bold').set_fontsize('14')

ax.grid(True)
ax.set_facecolor("whitesmoke")
# fig.autofmt_xdate(rotation=45, ha='right')
# ax.xaxis.set_major_locator(mdates.YearLocator())
# ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

ax.plot(x_axis, y_axis, color="magenta", linewidth= 2)

ax.legend(["USA Yearly Avg Temp (F)"], loc="upper left")

plt.tight_layout()
plt.savefig("./images/1878-2012_usa_temp_chart.png")
plt.show()

# %%
gltc2_df = gltc_df.loc[(gltc_df["country"] == "Canada") &
                       (gltc_df["year"]>= 1850)]
gltc2_df = gltc2_df.sort_values(["year"], ascending=[True]).\
                                reset_index(drop=True)
print(len(gltc2_df.index))
# Out:
# 163

# %%
# Get the min and max date range
gltc2_min_tmp = gltc2_df["avg_yly_tmp_f"].min()
gltc2_max_tmp = gltc2_df["avg_yly_tmp_f"].max()
print("min temperature (F) " + str(gltc2_min_tmp) +\
      " max temperature (F) " + str(gltc2_max_tmp))
# Out:
# min temperature (F) 19.5896 max temperature (F) 28.60175

# %%
# Get the min and max date range
gltc2_min_date = gltc2_df["year"].min()
gltc2_max_date = gltc2_df["year"].max()
print("min year " + str(gltc2_min_date) + " max year " + \
      str(gltc2_max_date))
# Out:
# min year 1850 max year 2012

# %%
# Dependencies
from matplotlib.figure import Figure
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import datetime as dt
from datetime import datetime, date, time
import matplotlib.dates as mdates

fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(111)

x_axis = gltc2_df["year"]  
y_axis = gltc2_df["avg_yly_tmp_f"]

ax.set_title("Canada Yearly Average Temperatures 1850 - 2012",\
             weight='bold').set_fontsize('18')
ax.set_xlabel("1850 - 2012",weight='bold').set_fontsize('14')
ax.set_ylabel("Yearly Average Temperatures(F)",weight='bold').set_fontsize('14')

ax.grid(True)
ax.set_facecolor("whitesmoke")
ax.plot(x_axis, y_axis, color="orange", linewidth= 2)

ax.legend(["Canada Yearly Avg Temp (F)"], loc="upper left")

plt.tight_layout()
plt.savefig("./images/1850-2012_canada_temp_chart.png")
plt.show()

# %%
gltc3_df = gltc_df.loc[(gltc_df["country"] == "France") &
                       (gltc_df["year"]>= 1850)]
gltc3_df = gltc3_df.sort_values(["year"], ascending=[True]).\
                                reset_index(drop=True)
print(len(gltc3_df.index))
# Out:
# 163

# %%
# Get the min and max date range
gltc3_min_tmp = gltc3_df["avg_yly_tmp_f"].min()
gltc3_max_tmp = gltc3_df["avg_yly_tmp_f"].max()
print("min temperature (F) " + str(gltc3_min_tmp) +\
      " max temperature (F) " + str(gltc3_max_tmp))
# Out:
# min temperature (F) 52.90055 max temperature (F) 58.06325

# %%
# Get the min and max date range
gltc3_min_date = gltc3_df["year"].min()
gltc3_max_date = gltc3_df["year"].max()
print("min year " + str(gltc3_min_date) + " max year " + \
      str(gltc3_max_date))
# Out:
# min year 1850 max year 2012

# %%
# Dependencies
from matplotlib.figure import Figure
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import datetime as dt
from datetime import datetime, date, time
import matplotlib.dates as mdates

fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(111)

x_axis = gltc3_df["year"]  
y_axis = gltc3_df["avg_yly_tmp_f"]

ax.set_title("France Yearly Average Temperatures 1850 - 2012",\
             weight='bold').set_fontsize('18')
ax.set_xlabel("1850 - 2012",weight='bold').set_fontsize('14')
ax.set_ylabel("Yearly Average Temperatures(F)",weight='bold').set_fontsize('14')

ax.grid(True)
ax.set_facecolor("whitesmoke")
ax.plot(x_axis, y_axis, color="red", linewidth= 2)

ax.legend(["France Yearly Avg Temp (F)"], loc="upper left")

plt.tight_layout()
plt.savefig("./images/1850-2012_france_temp_chart.png")
plt.show()

# %%
# Set the index to the date column for pandas df.plot()
gltc4_df = gltc_df.loc[(gltc_df["country"] == "Sweden") &
                       (gltc_df["year"]>= 1850)]
gltc4_df = gltc4_df.sort_values(["year"], ascending=[True]).\
                                reset_index(drop=True)
print(len(gltc4_df.index))
# Out:
# 163

# %%
# Get the min and max date range
gltc4_min_tmp = gltc4_df["avg_yly_tmp_f"].min()
gltc4_max_tmp = gltc4_df["avg_yly_tmp_f"].max()
print("min temperature (F) " + str(gltc4_min_tmp) +\
      " max temperature (F) " + str(gltc4_max_tmp))
# Out:
# min temperature (F) 32.21465 max temperature (F) 40.14605

# %%
# Get the min and max date range
gltc4_min_date = gltc4_df["year"].min()
gltc4_max_date = gltc4_df["year"].max()
print("min year " + str(gltc4_min_date) + " max year " + \
      str(gltc4_max_date))
# Out:
# min year 1850 max year 2012

# %%
# Dependencies
from matplotlib.figure import Figure
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import datetime as dt
from datetime import datetime, date, time
import matplotlib.dates as mdates

fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(111)

x_axis = gltc4_df["year"]  
y_axis = gltc4_df["avg_yly_tmp_f"]

ax.set_title("Sweden Yearly Average Temperatures 1850 - 2012",\
             weight='bold').set_fontsize('18')
ax.set_xlabel("1850 - 2012",weight='bold').set_fontsize('14')
ax.set_ylabel("Yearly Average Temperatures(F)",weight='bold').set_fontsize('14')

ax.grid(True)
ax.set_facecolor("whitesmoke")
ax.plot(x_axis, y_axis, color="blue", linewidth= 2)

ax.legend(["Sweden Yearly Avg Temp (F)"], loc="upper left")

plt.tight_layout()
plt.savefig("./images/1850-2012_sweden_temp_chart.png")
plt.show()

# %%
# Set the index to the date column for pandas df.plot()
gltc5_df = gltc_df.loc[(gltc_df["country"] == "Poland") &
                       (gltc_df["year"]>= 1850)]
gltc5_df = gltc5_df.sort_values(["year"], ascending=[True]).\
                                reset_index(drop=True)
print(len(gltc5_df.index))
# Out:
# 163

# %%
gltc5_min_tmp = gltc5_df["avg_yly_tmp_f"].min()
gltc5_max_tmp = gltc5_df["avg_yly_tmp_f"].max()
print("min temperature (F) " + str(gltc5_min_tmp) +\
      " max temperature (F) " + str(gltc5_max_tmp))
# Out:
# min temperature (F) 41.7209 max temperature (F) 49.3199

# %%
# Get the min and max date range
gltc5_min_date = gltc5_df["year"].min()
gltc5_max_date = gltc5_df["year"].max()
print("min year " + str(gltc5_min_date) + " max year " + \
      str(gltc5_max_date))
# Out:
# min year 1850 max year 2012

# %%
# Dependencies
from matplotlib.figure import Figure
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import datetime as dt
from datetime import datetime, date, time
import matplotlib.dates as mdates

fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(111)

x_axis = gltc5_df["year"]  
y_axis = gltc5_df["avg_yly_tmp_f"]

ax.set_title("Poland Yearly Average Temperatures 1850 - 2012",\
             weight='bold').set_fontsize('18')
ax.set_xlabel("1850 - 2012",weight='bold').set_fontsize('14')
ax.set_ylabel("Yearly Average Temperatures(F)",weight='bold').set_fontsize('14')

ax.grid(True)
ax.set_facecolor("whitesmoke")
ax.plot(x_axis, y_axis, color="green", linewidth= 2)

ax.legend(["Poland Yearly Avg Temp (F)"], loc="upper left")

plt.tight_layout()
plt.savefig("./images/1850-2012_poland_temp_chart.png")
plt.show()

# %%
# Set the index to the date column for pandas df.plot()
gltc6_df = gltc_df.loc[(gltc_df["country"] == "United Kingdom") &
                       (gltc_df["year"]>= 1850)]
gltc6_df = gltc6_df.sort_values(["year"], ascending=[True]).\
                                reset_index(drop=True)
print(len(gltc6_df.index))
# Out:
# 163

# %%
# Get the min and max date range
gltc6_min_tmp = gltc6_df["avg_yly_tmp_f"].min()
gltc6_max_tmp = gltc6_df["avg_yly_tmp_f"].max()
print("min temperature (F) " + str(gltc6_min_tmp) +\
      " max temperature (F) " + str(gltc6_max_tmp))
# Out:
# min temperature (F) 44.49035 max temperature (F) 49.89815

# %%
# Get the min and max date range
gltc6_min_date = gltc6_df["year"].min()
gltc6_max_date = gltc6_df["year"].max()
print("min year " + str(gltc6_min_date) + " max year " + \
      str(gltc6_max_date))
# Out:
# min year 1850 max year 2012

# %%
# Dependencies
from matplotlib.figure import Figure
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import datetime as dt
from datetime import datetime, date, time
import matplotlib.dates as mdates

fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(111)

x_axis = gltc6_df["year"]  
y_axis = gltc6_df["avg_yly_tmp_f"]

ax.set_title("UK Yearly Average Temperatures 1850 - 2012", weight='bold').set_fontsize('18')
ax.set_xlabel("1850 - 2012",weight='bold').set_fontsize('14')
ax.set_ylabel("Yearly Average Temperatures(F)",weight='bold').set_fontsize('14')

ax.grid(True)
ax.set_facecolor("whitesmoke")
ax.plot(x_axis, y_axis, color="purple", linewidth= 2)

ax.legend(["UK Yearly Avg Temp (F)"], loc="upper left")

plt.tight_layout()
plt.savefig("./images/1850-2012_uk_temp_chart.png")
plt.show()

# %%
# Set the index to the date column for pandas df.plot()
gltc7_df = gltc_df.loc[(gltc_df["country"] == "Spain") &
                       (gltc_df["year"]>= 1850)]
gltc7_df = gltc7_df.sort_values(["year"], ascending=[True]).\
                                reset_index(drop=True)
print(len(gltc7_df.index))
# Out:
# 163

# %%
# Get the min and max date range
gltc7_min_tmp = gltc7_df["avg_yly_tmp_f"].min()
gltc7_max_tmp = gltc7_df["avg_yly_tmp_f"].max()
print("min temperature (F) " + str(gltc7_min_tmp) +\
      " max temperature (F) " + str(gltc7_max_tmp))
# Out:
# min temperature (F) 54.59285 max temperature (F) 59.57795

# %%
# Get the min and max date range
gltc7_min_date = gltc7_df["year"].min()
gltc7_max_date = gltc7_df["year"].max()
print("min year " + str(gltc7_min_date) + " max year " + \
      str(gltc7_max_date))
# Out:
# min year 1850 max year 2012

# %%
# Dependencies
from matplotlib.figure import Figure
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import datetime as dt
from datetime import datetime, date, time
import matplotlib.dates as mdates

fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(111)

x_axis = gltc7_df["year"]  
y_axis = gltc7_df["avg_yly_tmp_f"]

ax.set_title("Spain Yearly Average Temperatures 1850 - 2012", weight='bold').set_fontsize('18')
ax.set_xlabel("1850 - 2012").set_fontsize('14')
ax.set_ylabel("Yearly Average Temperatures(F)").set_fontsize('14')

ax.grid(True)
ax.set_facecolor("whitesmoke")
ax.plot(x_axis, y_axis, color="cyan", linewidth= 2)

ax.legend(["Spain Yearly Avg Temp (F)"], loc="upper left")

plt.tight_layout()
plt.savefig("./images/1850-2012_spain_temp_chart.png")
plt.show()

# %%
# Set the index to the date column for pandas df.plot()
gltc8_df = gltc_df.loc[(gltc_df["country"] == "Australia") &
                       (gltc_df["year"]>= 1878)]
gltc8_df = gltc8_df.sort_values(["year"], ascending=[True]).\
                                reset_index(drop=True)
print(len(gltc8_df.index))
# Out:
# 135

# %%
# Get the min and max date range
gltc8_min_tmp = gltc8_df["avg_yly_tmp_f"].min()
gltc8_max_tmp = gltc8_df["avg_yly_tmp_f"].max()
print("min temperature (F) " + str(gltc8_min_tmp) +\
      " max temperature (F) " + str(gltc8_max_tmp))
# Out:
# min temperature (F) 69.3887 max temperature (F) 73.2143

# %%
# Get the min and max date range
gltc8_min_date = gltc8_df["year"].min()
gltc8_max_date = gltc8_df["year"].max()
print("min year " + str(gltc8_min_date) + " max year " + \
      str(gltc8_max_date))
# Out:
# min year 1878 max year 2012

# %%
# Dependencies
from matplotlib.figure import Figure
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import datetime as dt
from datetime import datetime, date, time
import matplotlib.dates as mdates

fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(111)

x_axis = gltc8_df["year"]  
y_axis = gltc8_df["avg_yly_tmp_f"]

ax.set_title("Australia Yearly Average Temperatures 1878 - 2012", weight='bold').set_fontsize('18')
ax.set_xlabel("1878 - 2012",weight='bold').set_fontsize('14')
ax.set_ylabel("Yearly Average Temperatures(F)",weight='bold').set_fontsize('14')

ax.grid(True)
ax.set_facecolor("whitesmoke")
ax.plot(x_axis, y_axis, color="maroon", linewidth= 2)

ax.legend(["Australia Yearly Avg Temp (F)"], loc="upper left")

plt.tight_layout()
plt.savefig("./images/1878-2012_australia_temp_chart.png")
plt.show()

# %%
# Set the index to the date column for pandas df.plot()
gltc9_df = gltc_df.loc[(gltc_df["country"] == "India") &
                       (gltc_df["year"]>= 1878)]
gltc9_df = gltc9_df.sort_values(["year"], ascending=[True]).\
                                reset_index(drop=True)
print(len(gltc9_df.index))
# Out:
# 135

# %%
# Get the min and max date range
gltc9_min_tmp = gltc9_df["avg_yly_tmp_f"].min()
gltc9_max_tmp = gltc9_df["avg_yly_tmp_f"].max()
print("min temperature (F) " + str(gltc9_min_tmp) +\
      " max temperature (F) " + str(gltc9_max_tmp))
# Out:
# min temperature (F) 73.2017 max temperature (F) 77.264

# %%
# Get the min and max date range
gltc9_min_date = gltc9_df["year"].min()
gltc9_max_date = gltc9_df["year"].max()
print("min year " + str(gltc9_min_date) + " max year " + \
      str(gltc9_max_date))
# Out:
# min year 1878 max year 2012

# %%
# Dependencies
from matplotlib.figure import Figure
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import datetime as dt
from datetime import datetime, date, time
import matplotlib.dates as mdates

fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(111)

x_axis = gltc9_df["year"]  
y_axis = gltc9_df["avg_yly_tmp_f"]

ax.set_title("India Yearly Average Temperatures 1878 - 2012", weight='bold').set_fontsize('18')
ax.set_xlabel("1878 - 2012",weight='bold').set_fontsize('14')
ax.set_ylabel("Yearly Average Temperatures(F)",weight='bold').set_fontsize('14')

ax.grid(True)
ax.set_facecolor("whitesmoke")
ax.plot(x_axis, y_axis, color="salmon", linewidth= 2)

ax.legend(["India Yearly Avg Temp (F)"], loc="upper left")

plt.tight_layout()
plt.savefig("./images/1878-2012_india_temp_chart.png")
plt.show()

# %%
from pandas.plotting import lag_plot

plt.figure()
data = gltc1_df["avg_yly_tmp_f"]
lag_plot(data)
plt.title("USA Yearly Avg TmpF Lag Plot")
plt.tight_layout()
plt.savefig("./images/usa_lag-plot_temp.png")
plt.show()

# %%
from matplotlib import pyplot as plt 
import numpy as np  
   
a = np.array(gltc1_df["avg_yly_tmp_f"]) 
plt.hist(a, bins='auto') 
plt.title("USA Yearly Avg TmpF Histogram")
plt.tight_layout()
plt.savefig("./images/usa_yly_avg_tmpf_histogram.png") 
plt.show()

# %%
from pandas.plotting import lag_plot

plt.figure()
data = gltc2_df["avg_yly_tmp_f"]
lag_plot(data)
plt.title("Canada Yearly Avg TmpF Lag Plot")
plt.tight_layout()
plt.savefig("./images/canada_lag-plot_temp.png")
plt.show()

# %%
from matplotlib import pyplot as plt 
import numpy as np  
   
a = np.array(gltc2_df["avg_yly_tmp_f"]) 
plt.hist(a, bins='auto') 
plt.title("Canada Yearly Avg TmpF Histogram")
plt.tight_layout()
plt.savefig("./images/canada_yly_avg_tmpf_histogram.png") 
plt.show()

# %%
from pandas.plotting import lag_plot

plt.figure()
data = gltc3_df["avg_yly_tmp_f"]
lag_plot(data)
plt.title("France Yearly Avg TmpF Lag Plot")
plt.tight_layout()
plt.savefig("./images/france_lag-plot_temp.png")
plt.show()

# %%
from matplotlib import pyplot as plt 
import numpy as np  
   
a = np.array(gltc3_df["avg_yly_tmp_f"]) 
plt.hist(a, bins='auto') 
plt.title("France Yearly Avg TmpF Histogram")
plt.tight_layout()
plt.savefig("./images/france_yly_avg_tmpf_histogram.png") 
plt.show()

# %%
from pandas.plotting import lag_plot

plt.figure()
data = gltc4_df["avg_yly_tmp_f"]
lag_plot(data)
plt.title("Sweden Yearly Avg TmpF Lag Plot")
plt.tight_layout()
plt.savefig("./images/sweden_lag-plot_temp.png")
plt.show()

# %%
from matplotlib import pyplot as plt 
import numpy as np  
   
a = np.array(gltc4_df["avg_yly_tmp_f"]) 
plt.hist(a, bins='auto') 
plt.title("Sweden Yearly Avg TmpF Histogram")
plt.tight_layout()
plt.savefig("./images/sweden_yly_avg_tmpf_histogram.png") 
plt.show()

# %%
from pandas.plotting import lag_plot

plt.figure()
data = gltc5_df["avg_yly_tmp_f"]
lag_plot(data)
plt.title("Poland Yearly Avg TmpF Lag Plot")
plt.tight_layout()
plt.savefig("./images/poland_lag-plot_temp.png")
plt.show()

# %%
from matplotlib import pyplot as plt 
import numpy as np  
   
a = np.array(gltc5_df["avg_yly_tmp_f"]) 
plt.hist(a, bins='auto') 
plt.title("Poland Yearly Avg TmpF Histogram")
plt.tight_layout()
plt.savefig("./images/poland_yly_avg_tmpf_histogram.png") 
plt.show()

# %%
from pandas.plotting import lag_plot

plt.figure()
data = gltc6_df["avg_yly_tmp_f"]
lag_plot(data)
plt.title("UK Yearly Avg TmpF Lag Plot")
plt.tight_layout()
plt.savefig("./images/uk_lag-plot_temp.png")
plt.show()

# %%
from matplotlib import pyplot as plt 
import numpy as np  
   
a = np.array(gltc6_df["avg_yly_tmp_f"]) 
plt.hist(a, bins='auto') 
plt.title("UK Yearly Avg TmpF Histogram")
plt.tight_layout()
plt.savefig("./images/uk_yly_avg_tmpf_histogram.png") 
plt.show()

# %%
from pandas.plotting import lag_plot

plt.figure()
data = gltc7_df["avg_yly_tmp_f"]
lag_plot(data)
plt.title("Spain Yearly Avg TmpF Lag Plot")
plt.tight_layout()
plt.savefig("./images/spain_lag-plot_temp.png")
plt.show()

# %%
from matplotlib import pyplot as plt 
import numpy as np  
   
a = np.array(gltc7_df["avg_yly_tmp_f"]) 
plt.hist(a, bins='auto') 
plt.title("Spain Yearly Avg TmpF Histogram")
plt.tight_layout()
plt.savefig("./images/spain_yly_avg_tmpf_histogram.png") 
plt.show()

# %%
from pandas.plotting import lag_plot

plt.figure()
data = gltc8_df["avg_yly_tmp_f"]
lag_plot(data)
plt.title("Australia Yearly Avg TmpF Lag Plot")
plt.tight_layout()
plt.savefig("./images/australia_lag-plot_temp.png")
plt.show()

# %%
from matplotlib import pyplot as plt 
import numpy as np  
   
a = np.array(gltc8_df["avg_yly_tmp_f"]) 
plt.hist(a, bins='auto') 
plt.title("Australia Yearly Avg TmpF Histogram")
plt.tight_layout()
plt.savefig("./images/australia_yly_avg_tmpf_histogram.png") 
plt.show()

# %%
from pandas.plotting import lag_plot

plt.figure()
data = gltc9_df["avg_yly_tmp_f"]
lag_plot(data)
plt.title("India Yearly Avg TmpF Lag Plot")
plt.tight_layout()
plt.savefig("./images/india_lag-plot_temp.png")
plt.show()

# %%
from matplotlib import pyplot as plt 
import numpy as np  
   
a = np.array(gltc9_df["avg_yly_tmp_f"]) 
plt.hist(a, bins='auto') 
plt.title("India Yearly Avg TmpF Histogram")
plt.tight_layout()
plt.savefig("./images/india_yly_avg_tmpf_histogram.png") 
plt.show()

# %%
# Dependencies
from matplotlib.figure import Figure
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import datetime as dt
from datetime import datetime, date, time
import matplotlib.dates as mdates

fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(111)

x_axis = gltc2_df["year"]  
y2_axis = gltc2_df["avg_yly_tmp_f"]
y3_axis = gltc3_df["avg_yly_tmp_f"]
y4_axis = gltc4_df["avg_yly_tmp_f"]
y5_axis = gltc5_df["avg_yly_tmp_f"]
y6_axis = gltc6_df["avg_yly_tmp_f"]
y7_axis = gltc7_df["avg_yly_tmp_f"]



ax.set_title("Yearly Avg Temp(F) by Country",\
             weight='bold').set_fontsize('18')
ax.set_xlabel("1850 - 2012", weight='bold').set_fontsize('14')
ax.set_ylabel("Yearly Avg Temps(F) by Country", 
              weight='bold').set_fontsize('14')

ax.grid(True)
ax.set_facecolor("whitesmoke")
fig.autofmt_xdate(rotation=45, ha='right')
# ax.xaxis.set_major_locator(mdates.YearLocator())
# ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

ax.plot(x_axis, y2_axis, color="orange", linewidth= 2)
ax.plot(x_axis, y3_axis, color="red", linewidth= 2)
ax.plot(x_axis, y4_axis, color="blue", linewidth= 2)
ax.plot(x_axis, y5_axis, color="green", linewidth= 2)
ax.plot(x_axis, y6_axis, color="purple", linewidth= 2)
ax.plot(x_axis, y7_axis, color="cyan", linewidth= 2)


ax.legend(["Canada Avg(F)","France Avg(F)","Sweden Avg(F)",
           "Poland Avg(F)","UK Avg(F)","Spain Avg(F)"], 
          loc='lower left', bbox_to_anchor=(0,.10))

plt.tight_layout()
plt.savefig("./images/yearly_avg_tempf_by_country.png")
plt.show()

# %%
# Dependencies
from matplotlib.figure import Figure
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import datetime as dt
from datetime import datetime, date, time
import matplotlib.dates as mdates

fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(111)

x_axis = gltc1_df["year"]  
y1_axis = gltc1_df["avg_yly_tmp_f"]
y8_axis = gltc8_df["avg_yly_tmp_f"]
y9_axis = gltc9_df["avg_yly_tmp_f"]




ax.set_title("Yearly Avg Temp(F) USA-AU-IN",\
             weight='bold').set_fontsize('18')
ax.set_xlabel("1878 - 2012", weight='bold').set_fontsize('14')
ax.set_ylabel("Yearly Avg Temps(F) USA-AU-IN", 
              weight='bold').set_fontsize('14')

ax.grid(True)
ax.set_facecolor("whitesmoke")
fig.autofmt_xdate(rotation=45, ha='right')

ax.plot(x_axis, y1_axis, color="magenta", linewidth= 2)
ax.plot(x_axis, y8_axis, color="limegreen", linewidth= 2)
ax.plot(x_axis, y9_axis, color="royalblue", linewidth= 2)



ax.legend(["USA Avg(F)","Australia Avg(F)","India Avg(F)"],
          bbox_to_anchor=(1.0,.65))

plt.tight_layout()
plt.savefig("./images/yearly_avg_tempf_usa-au-in.png")
plt.show()
